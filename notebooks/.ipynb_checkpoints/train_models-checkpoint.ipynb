# %%
import sys
import os

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '../')))

from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.base import clone
from lib.preprocessor import Preprocessor

import pandas as pd
import joblib

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 100)

models = {
    'logistic regression':OneVsRestClassifier(LogisticRegression()),
    'Decision tree': DecisionTreeClassifier(),
    'multi nomial': MultinomialNB()
}

grid_params_dict = {
    'logistic regression':{
        'estimator__solver': ['liblinear'],
        'estimator__penalty': ['l1', 'l2'],
    },
    'Decision tree':{
            'criterion': ['gini', 'entropy'],
            'max_depth': [None, 2, 4, 6, 8, 10],
            'min_samples_split': [2, 5, 10],
            'min_samples_leaf': [1, 2, 4]
        },
    'multi nomial' :{
    'alpha': [0.001, 0.01, 0.1, 0.5, 1.0, 2.0, 10.0],
    'fit_prior': [True, False]
    }
}

datasets_paths = joblib.load("../data/datasets_paths.pkl")


X       = joblib.load(datasets_paths[3][0])
y_train = joblib.load('../data/train_labels.pkl')


best_estimators = {}
for key, val in models.items():
    best_estimators[key] = None

for esti_name, param_grid in grid_params_dict.items():

    grid_search = GridSearchCV(
        estimator=models[esti_name],
        param_grid=param_grid,
        scoring='roc_auc_ovr',
        cv=5,
        n_jobs=-1
    )
    grid_search.fit(X, y_train)

    print(f"{esti_name}:")
    print(f"Best Alpha: {grid_search.best_params_}")
    print(f"Best Score: {grid_search.best_score_:.4f}")
    print("_________________________________________________")
    best_estimators[esti_name] = {"model":grid_search.best_estimator_, "params":grid_search.best_params_}

del X

df_test = pd.read_csv('../data/test.csv')
X_test = df_test["tweet"].values.tolist()
y_test = df_test["sentiment"].values.tolist()


results_dict = {
    'model':[],
    'preprocessing_method':[],
    'accuracy':[],
    'AUC':[],
    'best_hyper_params':[]
}


for path, approache in datasets_paths:
        
    X_train    = joblib.load(path)
    vectorizer = approache[0]
    
    X_test_processed, _ = Preprocessor.process(
        raws=X_test,
        processing_params={
            "method": None if approache[1] == 'only' else approache[1],
            },
            show_trans=False,
            vectorizer=vectorizer
    )
    
    for name, pair in best_estimators.items():
    
        copy_model = clone(pair["model"])
        copy_model.fit(X_train, y_train)
    
        y_pred = copy_model.predict(X_test_processed)
        y_prob = copy_model.predict_proba(X_test_processed)
        acc = accuracy_score(y_pred=y_pred, y_true=y_test)
        auc = roc_auc_score(y_test, y_prob, multi_class="ovr")

        results_dict['model'].append(name)
        results_dict['preprocessing_method'].append(f"{vectorizer.__class__.__name__} + {approache[1]}")
        results_dict['accuracy'].append(acc)
        results_dict['AUC'].append(auc)
        results_dict['best_hyper_params'].append(str(pair["params"]))


results_table = pd.DataFrame(data=results_dict)
print(results_table)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/isel-har/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/isel-har/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/isel-
# [nltk_data]     har/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/isel-
# [nltk_data]     har/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# logistic regression:
# Best Alpha: {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# Best Score: 0.9664
# _________________________________________________
# Decision tree:
# Best Alpha: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Best Score: 0.9432
# _________________________________________________
# multi nomial:
# Best Alpha: {'alpha': 1.0, 'fit_prior': True}
# Best Score: 0.9683
# _________________________________________________
#                   model               preprocessing_method  accuracy  \
# 0   logistic regression             CountVectorizer + only  0.898065
# 1         Decision tree             CountVectorizer + only  0.878710
# 2          multi nomial             CountVectorizer + only  0.880000
# 3   logistic regression             CountVectorizer + stem  0.896774
# 4         Decision tree             CountVectorizer + stem  0.877419
# 5          multi nomial             CountVectorizer + stem  0.873548
# 6   logistic regression        CountVectorizer + lemmatize  0.891613
# 7         Decision tree        CountVectorizer + lemmatize  0.870968
# 8          multi nomial        CountVectorizer + lemmatize  0.873548
# 9   logistic regression            CountVectorizer + stem+  0.860645
# 10        Decision tree            CountVectorizer + stem+  0.850323
# 11         multi nomial            CountVectorizer + stem+  0.859355
# 12  logistic regression      CountVectorizer + misspelling  0.892903
# 13        Decision tree      CountVectorizer + misspelling  0.854194
# 14         multi nomial      CountVectorizer + misspelling  0.869677
# 15  logistic regression  CountVectorizer + lem+misspelling  0.892903
# 16        Decision tree  CountVectorizer + lem+misspelling  0.851613
# 17         multi nomial  CountVectorizer + lem+misspelling  0.863226
# 18  logistic regression             CountVectorizer + only  0.895484
# 19        Decision tree             CountVectorizer + only  0.883871
# 20         multi nomial             CountVectorizer + only  0.889032
# 21  logistic regression             CountVectorizer + stem  0.896774
# 22        Decision tree             CountVectorizer + stem  0.876129
# 23         multi nomial             CountVectorizer + stem  0.873548
# 24  logistic regression        CountVectorizer + lemmatize  0.891613
# 25        Decision tree        CountVectorizer + lemmatize  0.878710
# 26         multi nomial        CountVectorizer + lemmatize  0.876129
# 27  logistic regression            CountVectorizer + stem+  0.860645
# 28        Decision tree            CountVectorizer + stem+  0.850323
# 29         multi nomial            CountVectorizer + stem+  0.855484
# 30  logistic regression      CountVectorizer + misspelling  0.889032
# 31        Decision tree      CountVectorizer + misspelling  0.846452
# 32         multi nomial      CountVectorizer + misspelling  0.864516
# 33  logistic regression  CountVectorizer + lem+misspelling  0.882581
# 34        Decision tree  CountVectorizer + lem+misspelling  0.854194
# 35         multi nomial  CountVectorizer + lem+misspelling  0.861935
# 36  logistic regression             TfidfVectorizer + only  0.889032
# 37        Decision tree             TfidfVectorizer + only  0.865806
# 38         multi nomial             TfidfVectorizer + only  0.885161
# 39  logistic regression             TfidfVectorizer + stem  0.894194
# 40        Decision tree             TfidfVectorizer + stem  0.869677
# 41         multi nomial             TfidfVectorizer + stem  0.872258
# 42  logistic regression        TfidfVectorizer + lemmatize  0.885161
# 43        Decision tree        TfidfVectorizer + lemmatize  0.873548
# 44         multi nomial        TfidfVectorizer + lemmatize  0.878710
# 45  logistic regression            TfidfVectorizer + stem+  0.858065
# 46        Decision tree            TfidfVectorizer + stem+  0.843871
# 47         multi nomial            TfidfVectorizer + stem+  0.852903
# 48  logistic regression      TfidfVectorizer + misspelling  0.886452
# 49        Decision tree      TfidfVectorizer + misspelling  0.840000
# 50         multi nomial      TfidfVectorizer + misspelling  0.861935
# 51  logistic regression  TfidfVectorizer + lem+misspelling  0.885161
# 52        Decision tree  TfidfVectorizer + lem+misspelling  0.841290
# 53         multi nomial  TfidfVectorizer + lem+misspelling  0.861935
#
#          AUC  \
# 0   0.977391
# 1   0.959598
# 2   0.977629
# 3   0.977279
# 4   0.953672
# 5   0.978323
# 6   0.978211
# 7   0.956873
# 8   0.978299
# 9   0.966760
# 10  0.941256
# 11  0.972241
# 12  0.974620
# 13  0.943692
# 14  0.974210
# 15  0.975742
# 16  0.942217
# 17  0.974588
# 18  0.977894
# 19  0.958972
# 20  0.977717
# 21  0.978070
# 22  0.951603
# 23  0.978618
# 24  0.979144
# 25  0.958407
# 26  0.978366
# 27  0.966758
# 28  0.943132
# 29  0.972340
# 30  0.973091
# 31  0.941988
# 32  0.973480
# 33  0.974421
# 34  0.937783
# 35  0.973456
# 36  0.978166
# 37  0.939871
# 38  0.973827
# 39  0.978585
# 40  0.936156
# 41  0.974988
# 42  0.979229
# 43  0.942436
# 44  0.975093
# 45  0.967622
# 46  0.936691
# 47  0.961843
# 48  0.974278
# 49  0.927754
# 50  0.969207
# 51  0.975142
# 52  0.921237
# 53  0.970540
#
#                                                                              best_hyper_params
# 0                               {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 1   {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 2                                                            {'alpha': 1.0, 'fit_prior': True}
# 3                               {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 4   {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 5                                                            {'alpha': 1.0, 'fit_prior': True}
# 6                               {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 7   {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 8                                                            {'alpha': 1.0, 'fit_prior': True}
# 9                               {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 10  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 11                                                           {'alpha': 1.0, 'fit_prior': True}
# 12                              {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 13  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 14                                                           {'alpha': 1.0, 'fit_prior': True}
# 15                              {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 16  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 17                                                           {'alpha': 1.0, 'fit_prior': True}
# 18                              {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 19  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 20                                                           {'alpha': 1.0, 'fit_prior': True}
# 21                              {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 22  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 23                                                           {'alpha': 1.0, 'fit_prior': True}
# 24                              {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 25  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 26                                                           {'alpha': 1.0, 'fit_prior': True}
# 27                              {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 28  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 29                                                           {'alpha': 1.0, 'fit_prior': True}
# 30                              {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 31  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 32                                                           {'alpha': 1.0, 'fit_prior': True}
# 33                              {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 34  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 35                                                           {'alpha': 1.0, 'fit_prior': True}
# 36                              {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 37  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 38                                                           {'alpha': 1.0, 'fit_prior': True}
# 39                              {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 40  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 41                                                           {'alpha': 1.0, 'fit_prior': True}
# 42                              {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 43  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 44                                                           {'alpha': 1.0, 'fit_prior': True}
# 45                              {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 46  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 47                                                           {'alpha': 1.0, 'fit_prior': True}
# 48                              {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 49  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 50                                                           {'alpha': 1.0, 'fit_prior': True}
# 51                              {'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
# 52  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 53                                                           {'alpha': 1.0, 'fit_prior': True}
