# %%
import sys
import os

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '../')))

from lib.data_preparation import DataPreparation
from lib.preprocessor import Preprocessor
import joblib

vec_approaches = ['binary', 'bow', 'tf-idf']
methods = [None, 'stem', 'lemmatize','stem+', 'misspelling', 'lem+misspelling']

df = DataPreparation.load()
df_train, _ = DataPreparation.save_train_test_split(df)

X = df_train["tweet"].values.tolist()
y = df_train["sentiment"].values.tolist()

joblib.dump(y, "../data/train_labels.pkl")

del y

datasets_paths = []

for vec_a in vec_approaches:
    
    for m in methods:

        print(f"vectorizer : {vec_a}, method {m}")
        X_transformed, vectorizer = Preprocessor.process(
            raws=X,
            processing_params={
            'vectorization':vec_a,
            'method':m
            },
            show_trans=False
        )

        method_used = 'only' if m == None else m

        path = f"../data/{vec_a}_{method_used}.pkl"
        joblib.dump(X_transformed, path)
        datasets_paths.append((path, (vectorizer, method_used)))


joblib.dump(datasets_paths, "../data/datasets_paths.pkl")
print("datasets are saved in ../data")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/isel-har/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/isel-har/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/isel-
# [nltk_data]     har/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/isel-
# [nltk_data]     har/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# vectorizer : binary, method None
# vectorizer : binary, method stem
# vectorizer : binary, method lemmatize
# vectorizer : binary, method stem+
# vectorizer : binary, method misspelling
# vectorizer : binary, method lem+misspelling
# vectorizer : bow, method None
# vectorizer : bow, method stem
# vectorizer : bow, method lemmatize
# vectorizer : bow, method stem+
# vectorizer : bow, method misspelling
# vectorizer : bow, method lem+misspelling
# vectorizer : tf-idf, method None
# vectorizer : tf-idf, method stem
# vectorizer : tf-idf, method lemmatize
# vectorizer : tf-idf, method stem+
# vectorizer : tf-idf, method misspelling
# vectorizer : tf-idf, method lem+misspelling
# datasets are saved in ../data
