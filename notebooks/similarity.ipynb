# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from preprocessor import Preprocessor

pre_proccesses =[
    {'method': None, 'vectorization':'binary'},
    {'method':'stem', 'vectorization':'binary'},
    {'method':'stem', 'vectorization':'bow'},
    {'method':'lemmatize', 'vectorization':'bow'},
    {'method':'stem', 'vectorization':'tf-idf'},
    {'method':'stem+', 'vectorization':'tf-idf'},
    {'method':'lemmatize', 'vectorization':'tf-idf', 'stopwords':True},
    {'method':'lemmatize', 'vectorization':'word2vec', 'stopwords':True},
]
# load train test split of raw tweets
data = np.load("dataset_split.npz")

X_train = data["X_train"]
X_test  = data["X_test"]

tweets = np.concatenate([X_train, X_test])

for proc in pre_proccesses:
    X = Preprocessor.process(tweets, proc)
    
    cos_sim = cosine_similarity(X)
    pairs = []

    n = len(tweets)
    for i in range(n):
        for j in range(i + 1, n):  # avoid duplicates & self-pairs
            pairs.append((i, j, cos_sim[i, j]))
    
    # # sort by similarity (descending)
    top_10 = sorted(pairs, key=lambda x: x[2], reverse=True)[:10]
    print(f"top 10 similar pair tweets using method {proc['method']}, vectorization {proc['vectorization']}")
    for i, j, score in top_10:
        print(f"[{score:.3f}]")
        print("Tweet A:", tweets[i])
        print("Tweet B:", tweets[j])
        print("-" * 50)
# Out:
# top 10 similar pair tweets using method:None, vectorization:binary
# [1.000]
# Tweet A: are dying of thirst  and it's all because of us unhappy   .1
# Tweet B: are dying of thirst  and it's all because of us unhappy
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..12
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..18
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..9
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..16
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..26
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..4
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..32
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..6
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..24
# --------------------------------------------------
# top 10 similar pair tweets using method:stem, vectorization:binary
# [1.000]
# Tweet A: Hi! We tried to call your number but got no response unhappy  Please share another suitable time and an alternate number.. cont1.1
# Tweet B: Hi! We tried to call your number but got no response unhappy  Please share another suitable time and an alternate number.. cont1
# --------------------------------------------------
# [1.000]
# Tweet A: are dying of thirst  and it's all because of us unhappy   .1
# Tweet B: are dying of thirst  and it's all because of us unhappy
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..12
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..18
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..9
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..16
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..26
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..4
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..32
# --------------------------------------------------
# [1.000]
# Tweet A: Thanks for the recent follow Happy to connect happy  have a great Thursday..10
# Tweet B: Thanks for the recent follow Happy to connect happy  have a great Thursday..6
# --------------------------------------------------
# top 10 similar pair tweets using method:stem, vectorization:bow
# [1.000]
# Tweet A: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.6
# Tweet B: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.5
# --------------------------------------------------
# [1.000]
# Tweet A: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.6
# Tweet B: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.1
# --------------------------------------------------
# [1.000]
# Tweet A: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.6
# Tweet B: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.3
# --------------------------------------------------
# [1.000]
# Tweet A: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.6
# Tweet B: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.4
# --------------------------------------------------
# [1.000]
# Tweet A: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.6
# Tweet B: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.7
# --------------------------------------------------
# [1.000]
# Tweet A: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.6
# Tweet B: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.2
# --------------------------------------------------
# [1.000]
# Tweet A: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.6
# Tweet B: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.8
# --------------------------------------------------
# [1.000]
# Tweet A: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.6
# Tweet B: talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not
# --------------------------------------------------
# [1.000]
# Tweet A: Idea itself wrong
# Tweet B: Idea itself wrong.1
# --------------------------------------------------
# [1.000]
# Tweet A: Her back unhappy  .3
# Tweet B: Her back unhappy
# --------------------------------------------------
# top 10 similar pair tweets using method:lemmatize, vectorization:bow
# [1.000]
# Tweet A: Idea itself wrong
# Tweet B: Idea itself wrong.1
# --------------------------------------------------
# [1.000]
# Tweet A: Her back unhappy  .3
# Tweet B: Her back unhappy
# --------------------------------------------------
# [1.000]
# Tweet A: Her back unhappy  .3
# Tweet B: Her back unhappy  .1
# --------------------------------------------------
# [1.000]
# Tweet A: Her back unhappy  .3
# Tweet B: Her back unhappy  .2
# --------------------------------------------------
# [1.000]
# Tweet A: Her back unhappy  .3
# Tweet B: Her back unhappy  .4
# --------------------------------------------------
# [1.000]
# Tweet A: THANK YOU happy
# Tweet B: Thank you happy
# --------------------------------------------------
# [1.000]
# Tweet A: THANK YOU happy
# Tweet B:  Thank you happy
# --------------------------------------------------
# [1.000]
# Tweet A: THANK YOU happy
# Tweet B: thank you happy
# --------------------------------------------------
# [1.000]
# Tweet A: THANK YOU happy
# Tweet B: Thank you! happy
# --------------------------------------------------
# [1.000]
# Tweet A: THANK YOU happy
# Tweet B:  thank you happy
# --------------------------------------------------
# top 10 similar pair tweets using method:stem, vectorization:tf-idf
# [1.000]
# Tweet A: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .2
# Tweet B: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .5
# --------------------------------------------------
# [1.000]
# Tweet A: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .2
# Tweet B: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways
# --------------------------------------------------
# [1.000]
# Tweet A: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .2
# Tweet B: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .7
# --------------------------------------------------
# [1.000]
# Tweet A: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .2
# Tweet B: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .9
# --------------------------------------------------
# [1.000]
# Tweet A: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .2
# Tweet B: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .1
# --------------------------------------------------
# [1.000]
# Tweet A: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .2
# Tweet B: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .3
# --------------------------------------------------
# [1.000]
# Tweet A: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .2
# Tweet B: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .8
# --------------------------------------------------
# [1.000]
# Tweet A: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .2
# Tweet B: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .6
# --------------------------------------------------
# [1.000]
# Tweet A: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .2
# Tweet B: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .10
# --------------------------------------------------
# [1.000]
# Tweet A: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .2
# Tweet B: YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways .4
# --------------------------------------------------
# top 10 similar pair tweets using method:stem+, vectorization:tf-idf
# [1.000]
# Tweet A:  music and direction by of my favourites by
# Tweet B:  music and direction by of my favourites by.1
# --------------------------------------------------
# [1.000]
# Tweet A: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon
# Tweet B: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon.2
# --------------------------------------------------
# [1.000]
# Tweet A: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon
# Tweet B: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon.3
# --------------------------------------------------
# [1.000]
# Tweet A: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon
# Tweet B: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon.4
# --------------------------------------------------
# [1.000]
# Tweet A: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon
# Tweet B: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon.1
# --------------------------------------------------
# [1.000]
# Tweet A: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon.2
# Tweet B: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon.3
# --------------------------------------------------
# [1.000]
# Tweet A: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon.2
# Tweet B: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon.4
# --------------------------------------------------
# [1.000]
# Tweet A: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon.2
# Tweet B: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon.1
# --------------------------------------------------
# [1.000]
# Tweet A: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon.3
# Tweet B: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon.4
# --------------------------------------------------
# [1.000]
# Tweet A: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon.3
# Tweet B: Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon.1
# --------------------------------------------------
# top 10 similar pair tweets using method:lemmatize, vectorization:tf-idf
# [1.000]
# Tweet A: Thank you crew happy.4
# Tweet B: Thank you crew happy.3
# --------------------------------------------------
# [1.000]
# Tweet A: Thank you crew happy.4
# Tweet B: Thank you crew happy.1
# --------------------------------------------------
# [1.000]
# Tweet A: Thank you crew happy.4
# Tweet B: Thank you crew happy
# --------------------------------------------------
# [1.000]
# Tweet A: Thank you crew happy.4
# Tweet B: Thank you crew happy.2
# --------------------------------------------------
# [1.000]
# Tweet A: I only just absorbed that I'm not going to get to laugh when he gets 2000 votes. unhappy  .2
# Tweet B: I only just absorbed that I'm not going to get to laugh when he gets 2000 votes. unhappy  .1
# --------------------------------------------------
# [1.000]
# Tweet A: I only just absorbed that I'm not going to get to laugh when he gets 2000 votes. unhappy  .2
# Tweet B: I only just absorbed that I'm not going to get to laugh when he gets 2000 votes. unhappy  .4
# --------------------------------------------------
# [1.000]
# Tweet A: I only just absorbed that I'm not going to get to laugh when he gets 2000 votes. unhappy  .2
# Tweet B: I only just absorbed that I'm not going to get to laugh when he gets 2000 votes. unhappy  .3
# --------------------------------------------------
# [1.000]
# Tweet A: I only just absorbed that I'm not going to get to laugh when he gets 2000 votes. unhappy  .2
# Tweet B: I only just absorbed that I'm not going to get to laugh when he gets 2000 votes. unhappy
# --------------------------------------------------
# [1.000]
# Tweet A: Govt seems to have slipped in an in Budget2017.
# Tweet B: Govt seems to have slipped in an in Budget2017. .1
# --------------------------------------------------
# [1.000]
# Tweet A: I only just absorbed that I'm not going to get to laugh when he gets 2000 votes. unhappy  .1
# Tweet B: I only just absorbed that I'm not going to get to laugh when he gets 2000 votes. unhappy  .4
# --------------------------------------------------
# top 10 similar pair tweets using method:lemmatize, vectorization:word2vec
# [1.000]
# Tweet A: Koalas are dying of thirst  and it's all because of us unhappy  .3
# Tweet B: Koalas are dying of thirst  and it's all because of us unhappy  .12
# --------------------------------------------------
# [1.000]
# Tweet A: Koalas are dying of thirst  and it's all because of us unhappy  .3
# Tweet B: Koalas are dying of thirst  and it's all because of us unhappy  .7
# --------------------------------------------------
# [1.000]
# Tweet A: Koalas are dying of thirst  and it's all because of us unhappy  .3
# Tweet B: Koalas are dying of thirst  and it's all because of us unhappy  .11
# --------------------------------------------------
# [1.000]
# Tweet A: Koalas are dying of thirst  and it's all because of us unhappy  .3
# Tweet B: Koalas are dying of thirst  and it's all because of us unhappy  .2
# --------------------------------------------------
# [1.000]
# Tweet A: Koalas are dying of thirst  and it's all because of us unhappy  .3
# Tweet B: Koalas are dying of thirst  and it's all because of us unhappy  .10
# --------------------------------------------------
# [1.000]
# Tweet A: Koalas are dying of thirst  and it's all because of us unhappy  .3
# Tweet B: Koalas are dying of thirst  and it's all because of us unhappy
# --------------------------------------------------
# [1.000]
# Tweet A: Koalas are dying of thirst  and it's all because of us unhappy  .3
# Tweet B: Koalas are dying of thirst  and it's all because of us unhappy  .14
# --------------------------------------------------
# [1.000]
# Tweet A: Koalas are dying of thirst  and it's all because of us unhappy  .3
# Tweet B: Koalas are dying of thirst  and it's all because of us unhappy  .4
# --------------------------------------------------
# [1.000]
# Tweet A: Koalas are dying of thirst  and it's all because of us unhappy  .3
# Tweet B: Koalas are dying of thirst  and it's all because of us unhappy  .6
# --------------------------------------------------
# [1.000]
# Tweet A: Koalas are dying of thirst  and it's all because of us unhappy  .3
# Tweet B: Koalas are dying of thirst  and it's all because of us unhappy  .13
# --------------------------------------------------
